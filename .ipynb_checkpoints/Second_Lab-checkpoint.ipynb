# %% [markdown]
# 1. <a href="#1">Read the dataset</a>
# 2. <a href="#2">Data investigation</a>
# 3. <a href="#3">Data preprocessing </a>
# 4. <a href="#4">Features transformation </a>
# 4. <a href="#5">Training datasets</a>
# 5. <a href="#6">Improvement ideas</a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. <a name="1">Read the dataset</a>
# (<a href="#0">Go to top</a>)

# %%
df = pd.read_excel('default of credit card clients.xls',header = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a3081f2b722> in <module>
# ----> 1 df = pd.read_excel('default of credit card clients.xls',header = 1)
#
# NameError: name 'pd' is not defined

# %%
df.head()

# %%
df.info()

# %%
df.shape

# %%
round(df.isnull().sum()*100/df.shape[0],2)

# %%
df['EDUCATION'] = df.EDUCATION.fillna(df.EDUCATION.mode()[0])

# %%
df['MARRIAGE'] = df.MARRIAGE.fillna(df.MARRIAGE.mode()[0])

# %%
# df.dropna(inplace = True)

# %%
df.MARRIAGE.mode()[0]

# %%
round(df.isnull().sum()*100/df.shape[0],2)

# %%
df.shape

# %%
# df.drop(columns = ['ID'],inplace= True)

# %%
df.SEX.value_counts()

# %%
df.EDUCATION.value_counts()

# %%
df.EDUCATION = df.EDUCATION.replace({0:np.nan})

# %%
df.EDUCATION.value_counts(dropna = False)

# %%
df['EDUCATION'] = df.EDUCATION.fillna(df.EDUCATION.mode()[0])

# %%
df[df.duplicated(keep = False)]

# %%
df.loc[:,['AGE','EDUCATION']].duplicated().sum()

# %%
df[['AGE','EDUCATION']]

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape

# %%
drop_index = df[df[['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE']].duplicated()].index

# %%
# df.drop(index = drop_index,inplace= True)

# %%
AGE_drop = df.loc[df.AGE > 100,['AGE','EDUCATION']].index

# %%
df.drop(index = AGE_drop,inplace = True)

# %%
df.AGE.plot(kind = 'hist',bins = 20)

# %%
arr = np.arange(15).reshape(3,5)

# %%
df = pd.DataFrame(arr,columns = ['A','B','C','D','E'],index= [10,20,30])

# %%
df[['high school','others','university']] = pd.get_dummies(df.EDUCATION,drop_first=True)

# %%
df.columns

# %%
df.drop(columns = ['EDUCATION'],inplace = True)

# %%
pd.get_dummies(df.SEX)

# %%
df = df.drop(columns = ['default payment next month']).assign(output = df['default payment next month'])

# %%
#read the data

data_path = 'countries of the world.csv'  #the path where you downloaded the data
df = pd.read_csv('countries of the world.csv')

print('The shape of the dataset is:', df.shape)

# %%
df.tail()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## 2. <a name="2">Data investigation</a>
# (<a href="#0">Go to top</a>)
#
# in this part you need to check the data quality and assess any issues in the data as:
# - null values in each column
# - each column has the proper data type
# - outliers
# - duplicate rows
# - distribution for each column (skewness)
# <br>
#
# **comment each issue you find**

# %%
# Let's see the data types and non-null values for each column
df.info()

# %%
round(df.isnull().sum(axis=0)*100/df.shape[0],2)

# %%
# This will print basic statistics for numerical columns
df.describe()

# %% [markdown]
# ## 3. <a name="3">Data preprocessing</a>
# (<a href="#0">Go to top</a>)

# %% [markdown]
# ### Define below all the issues that you had found in the previous part
# 1-           <br>
# 2-           <br>
# 3-           <br>

# %%
#make a copy for the original dataset
df_copy=df.copy()

# %% [markdown]
# ### for each issue adapt this methodology
# - start by defining the solution
# - apply this solution onn the data
# - test the solution to make sure that you have solved the issue

# %% [markdown]
# **First issue**

# %%
#solution

# %%
#test

# %% [markdown]
# **Second issue**

# %%
#solution

# %%
#test

# %% [markdown]
# ## 4. <a name="4">Features transformation</a>
# (<a href="#0">Go to top</a>)

# %% [markdown]
# *What is the feature scaling technique that would use and why?* <br>
# *return to this section again and try another technique and see how that will impact your result*<br>
# for more details on different methods for scaling check these links
# - https://scikit-learn.org/stable/modules/preprocessing.html#preprocessing
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing
# - https://www.analyticsvidhya.com/blog/2020/07/types-of-feature-transformation-and-scaling/

# %%
from sklearn import preprocessing

# %%
df.drop(columns = ['MARRIAGE'],inplace = True)

# %% [markdown]
# ## 5. <a name="5">Training and hyperparamter tuning</a>
# (<a href="#0">Go to top</a>)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,:-1],df.iloc[:,-1] ,test_size=0.3, shuffle=True, 
                                         random_state=23,stratify=df.iloc[:,-1])

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0,max_depth=8,min_samples_split=4)

# %%
clf.fit(X_train,y_train)

# %%
clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(clf.predict(X_test),y_test)

# %%
accuracy_score(clf.predict(X_train),y_train)

# %% [markdown]
# ## 6. <a name="6">improvement ideas</a>
# (<a href="#0">Go to top</a>)

# %% [markdown]
# - Try to use PCA to reduce the number of features and compare how this will affect the clustring process
# - Try to run your code again but with different tranformation technique
# - Implement gap statistics method and use it as evaluation metric and compare the result with what you did before https://www.datanovia.com/en/lessons/determining-the-optimal-number-of-clusters-3-must-know-methods/#gap-statistic-method
